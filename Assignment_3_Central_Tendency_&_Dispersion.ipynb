# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as stat

# %%
data=pd.read_csv('/Users/nidhi.anil/Downloads/StudentsPerformance.csv')

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
# 1  female        group B                 high school  free/reduced
# 2  female        group B            some high school  free/reduced
# 3  female        group B                some college      standard
# 4  female        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none           0             17             10
# 1                    none           8             24             23
# 2                    none          18             32             28
# 3                    none          11             38             32
# 4                    none          22             39             33

# %% [markdown]
# # 1. Find out how many males females participated in the test.

# %%
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# # 2. What do you think about the students's parental level of education?

# %%
data['average score']=(data['math score']+data['writing score']+data['reading score']/3)

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
# 1  female        group B                 high school  free/reduced
# 2  female        group B            some high school  free/reduced
# 3  female        group B                some college      standard
# 4  female        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none           0             17             10
# 1                    none           8             24             23
# 2                    none          18             32             28
# 3                    none          11             38             32
# 4                    none          22             39             33
#
#    average score
# 0      15.666667
# 1      39.000000
# 2      56.666667
# 3      55.666667
# 4      68.000000

# %%
data['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
sns.countplot(x='parental level of education',data=data)
plt.xticks(rotation=45)
plt.title('Students parental level of education')
plt.show()

# From the above analysis, we can infer that the students with high school as parental level of education have the lowest average score and students with an associate's degree and a bachelor's degree as parental levels of education have the same average score.

# Most of the students belong to 'some college' category.

# %%
plt.bar(data['parental level of education'],data['average score'])
plt.xticks(rotation=45)
plt.title('Distribution of Parental level of Education v/s Average Score')
plt.show()

# %% [markdown]
# # 3. Who scores the most on average for math,reading and writing based on Gender & Test preparation course?

# %%
data.groupby('gender')['math score','reading score','writing score'].mean()
# Out:
# /var/folders/rh/zmjyr39j5y9_jmlgy4_cl6600000gp/T/ipykernel_20673/1961774292.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('gender')['math score','reading score','writing score'].mean()
#         math score  reading score  writing score
# gender
# female   63.376448      72.590734      72.467181
# male     68.821577      65.545643      63.446058

# %%
# Male students have higher average math score than female students.
# Female students have higher average reading & writing score than male students.

# %%
data.groupby('test preparation course')['math score','reading score','writing score'].mean()
# Out:
# /var/folders/rh/zmjyr39j5y9_jmlgy4_cl6600000gp/T/ipykernel_20673/49402056.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('test preparation course')['math score','reading score','writing score'].mean()
#                          math score  reading score  writing score
# test preparation course
# completed                  69.96648      74.175978      74.684358
# none                       63.78972      66.417445      64.457944

# %%
# Students who have completed the test preparation course score higher average marks for math, reading, and writing than those who don't complete the course.

# %% [markdown]
# # 4. What do you think about the scoring variation for math,reading and writing based on Gender & Test preparation course?

# %%
sns.barplot(x='gender',y='math score',data=data)
plt.title('Math Scores')
plt.show()

# %%
stat.variance(data['math score'])
# Out:
# 242.4114104104104

# %%
stat.stdev(data['math score'])
# Out:
# 15.569566802272002

# %%
sns.barplot(x='gender',y='reading score',data=data)
plt.title('Reading Scores')
plt.show()

# %%
stat.variance(data['reading score'])
# Out:
# 216.27925425425425

# %%
stat.stdev(data['reading score'])
# Out:
# 14.706435810700507

# %%
sns.barplot(x='gender',y='writing score',data=data)
plt.title('Writing Scores')
plt.show()

# %%
stat.variance(data['writing score'])
# Out:
# 231.84268168168168

# %%
stat.stdev(data['writing score'])
# Out:
# 15.226381109169758

# %%
# We can see that male students scored higher in Maths and female students scored higher in Reading and Writing.

# %%
sns.barplot(x='test preparation course',y='math score',hue='gender',data=data)
plt.title('Test preparation v/s Math Score')
plt.show()

# %%
sns.barplot(x='test preparation course',y='reading score',hue='gender',data=data)
plt.title('Test preparation v/s Reading Score')
plt.show()

# %%
sns.barplot(x='test preparation course',y='writing score',hue='gender',data=data)
plt.title('Test preparation v/s Writing Score')
plt.show()

#The students(Male & Female) who completed the test preparation course scored higher in all three subjects.

# %% [markdown]
# # 5. The management needs your help to give bonus points to the top 25% of students based on their math score, so how will you help?

# %%
data['math score'].quantile(0.75)
# Out:
# 77.0

# %%
Top_25= data[data['math score']>=77].sort_values('math score',ascending=False)
Top_25
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999    male        group E           bachelor's degree      standard
# 998    male        group E          associate's degree  free/reduced
# 997    male        group D                some college      standard
# 996    male        group A                some college      standard
# 517  female        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 854    male        group D            some high school      standard
# 855    male        group E          associate's degree  free/reduced
# 856    male        group E            some high school      standard
# 415  female        group B             master's degree  free/reduced
# 414  female        group A                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 999               completed         100            100            100
# 998               completed         100            100             93
# 997               completed         100             97             99
# 996               completed         100             96             86
# 517                    none         100            100            100
# ..                      ...         ...            ...            ...
# 854               completed          77             68             69
# 855               completed          77             69             68
# 856               completed          77             76             77
# 415               completed          77             97             94
# 414               completed          77             88             85
#
#      average score
# 999     233.333333
# 998     226.333333
# 997     231.333333
# 996     218.000000
# 517     233.333333
# ..             ...
# 854     168.666667
# 855     168.000000
# 856     179.333333
# 415     203.333333
# 414     191.333333
#
# [255 rows x 9 columns]
